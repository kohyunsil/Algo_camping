# %%
import pandas as pd

# %%
import nlp_clustering as nc
nlp = nc.NlpCluster()

# %%
df = nlp.nlp_clustering(vec='tfidf', min_cluster_size=30)
# Out:
#   2%|▏         | 28/1442 [00:00<00:05, 274.71it/s]
#                     addr1 allar animalCmgCl autoSiteCo brazierCl  \
# 0  경남 밀양시 삼랑진읍 행곡3길 65-34     0         불가능          0        개별
# 1     경북 성주군 금수면 성주로 15-4     0         불가능          0        개별
# 2     경북 김천시 농소면 벽봉로 1651     0         불가능          0        개별
# 3  충남 태안군 남면 진산1길 277-112     0         불가능          0        개별
# 4     충남 보령시 웅천읍 내성1길 117     0         불가능          0        개별
#
#   caravAcmpnyAt caravSiteCo clturEventAt contentId          createdtime  ...  \
# 0             N           0            N      7934  2021-02-18 17:25:12  ...
# 1             N           0            N      7935  2021-02-18 17:25:12  ...
# 2             N           0            N      7936  2021-02-18 17:25:12  ...
# 3             N           0            N      7939  2021-02-18 17:25:12  ...
# 4             N           0            N      7940  2021-02-18 17:25:12  ...
#
# ...

# %%
df2 = df[["contentId", "facltNm", "full_text", "cluster"]].copy()
df2.to_csv("results/nlp_cluster_lineintro20.csv", encoding='utf-8-sig')

# %%
df2
# Out:
#      contentId       facltNm  \
# 0         7965         몽골캠핑장
# 1         7969       고운마을캠핑장
# 2         7971         솔미캠핑장
# 3         7977        강나루야영장
# 4         7980      스카이랜드리조트
# ...        ...           ...
# 1437      6806     뱀사골 힐링야영장
# 1438      3289   포항오토캠핑장 루트7
# 1439      3434  함평나비마을 서울캠핑장
# 1440      3436       함허동천야영장
# 1441      3440  합천 아마존 오토캠핑장
#
#                                               full_text  cluster
# 0        맑은공기와 바로옆에 계곡이있다 소규모 캠핑장으로 가족적인 분위기로 편하다쉬다곳이다.       -1
# 1     의성군에서 2019년 5월에 준공한 신규캠핑장이다.지금은 활기차다지역만들기협동조합에...       12
# 2                                           솔향가득~~~힐링공간       12
# 3                             교외에 소규모로 운영하고 있다 야영캠핑장이다.       -1
# 4                 한폭의 수채화를 연상시키다 저녁 노을이 있다 스카이랜드 카라반 호텔        3
# ...                                                 ...      ...
# 1437                  30년이 넘다 역사를 자랑하다 뱀사골 힐링야영장에서 힐링을!       12
# 1438                           폐교가 감성적인 캠핑장으로 다시 태어나다 곳       -1
# ...
